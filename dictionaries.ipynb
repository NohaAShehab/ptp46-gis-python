# %%
info = ["Noha",33, "iti"] #unlabeled data

# %%
# data type --> support adding description for values
# struct --> {name="sad", email=add, add}

# dictionary ?
dd = dict()
info = {
    "name": "Noha",
    "age": 33,
    "work": "iti",
    "name": "Noha Sheheb"
}
print(info)

# comma separated key:value pair --> doesn't key duplications
# Out:
# {'name': 'Noha Sheheb', 'age': 33, 'work': 'iti'}

# %%
# mutable datatype
# access elements using keys ?
print(info["age"])
# Out:
# 33

# %%
info["name"]='Noha Abdelhady'
print(info)
# Out:
# {'name': 'Noha Abdelhady', 'age': 33, 'work': 'iti'}

# %%
info["city"] = "Mansoura"
print(info)
# Out:
# {'name': 'Noha Abdelhady', 'age': 33, 'work': 'iti', 'city': 'Mansoura'}

# %%
# before python 3.7 # dict wasn't ordered
### after this version is ordered based on the ordered you the key:value pairs

# get len of dict
print(len(info))
# Out:
# 4

# %%
# check element exists in dict or not ?
print(33 in info)
# Out:
# False

# %%
# using in operator with dict --? search about values in keys ---??

print("age" in info) # search in keys of dicts..?
# Out:
# True

# %%
# for loop in dict --> iterable
for item in info:
    print(item)
# Out:
# name
# age
# work
# city

# %%
for item in info: # item ==> refers to the key
    print(f"{item} is {info[item]}")
# Out:
# name is Noha Abdelhady
# age is 33
# work is iti
# city is Mansoura

# %%
print(info)
# Out:
# {'name': 'Noha Abdelhady', 'age': 33, 'work': 'iti', 'city': 'Mansoura'}

# %%
# I need to get dict keys

d_keys = info.keys()
print(d_keys)
# Out:
# dict_keys(['name', 'age', 'work', 'city'])

# %%
print(list(info.keys()))
# Out:
# ['name', 'age', 'work', 'city']

# %%
d_values = info.values()
print(d_values)
# Out:
# dict_values(['Noha Abdelhady', 33, 'iti', 'Mansoura'])

# %%
print(list(info.values()))
# Out:
# ['Noha Abdelhady', 33, 'iti', 'Mansoura']

# %%
# Items ?
d_items = info.items()
print(d_items)
# Out:
# dict_items([('name', 'Noha Abdelhady'), ('age', 33), ('work', 'iti'), ('city', 'Mansoura')])

# %%
items_list = list(d_items)

# %%
# need key, value from dict

for key , value in info.items():
    print(key, value)
# Out:
# name Noha Abdelhady
# age 33
# work iti
# city Mansoura

# %%
# update dict

add_info = {
    "academic" : "Masters",
    "name" : "noha",
    "courses" : ["python", "mongo"],
    "salary" : 3000
}

print(info)
# Out:
# {'name': 'Noha Abdelhady', 'age': 33, 'work': 'iti', 'city': 'Mansoura'}

# %%
info.update(add_info)

print(info)
# Out:
# {'name': 'noha', 'age': 33, 'work': 'iti', 'city': 'Mansoura', 'academic': 'Masters', 'courses': ['python', 'mongo'], 'salary': 3000}

# %%
# del
del info['academic']
print(info)
# Out:
# {'name': 'noha', 'age': 33, 'work': 'iti', 'city': 'Mansoura', 'courses': ['python', 'mongo'], 'salary': 3000}

# %%
# remove element from dict
popped_element = info.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # remove element from dict
# ----> 2 popped_element = info.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
popped_element = info.pop("name")
print(info)
# Out:
# {'age': 33, 'work': 'iti', 'city': 'Mansoura', 'courses': ['python', 'mongo'], 'salary': 3000}

# %%
print(info)
info.clear()
print(info)
# Out:
# {'age': 33, 'work': 'iti', 'city': 'Mansoura', 'courses': ['python', 'mongo'], 'salary': 3000}
# {}

# %%
del info  # remove object from memory
