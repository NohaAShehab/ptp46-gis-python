# %% [markdown]
# <h1 style='color:yellow; text-align:center;'>Encapsulation </h1>

# %%
"""
    encapsulation ::: access modifiers ?
    --> public
    --> protected
    --> private

    Python says that NO ACCESS MODIFIERS IN PYTHON
    # use name convention ?
    public ---> [a-z: ]
    protected ---> [_:]
    private ---> [__:]

"""

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.__salary = salary


emp = Employee("noha", 'noha@gmail.com',50000)

# %%
print(emp.name) # public
emp.name = 'updated'
print(emp.name)
# Out:
# noha
# updated

# %% [markdown]
# - Ethically don't this ? don't access protected members using object

# %%
# protected
print(emp._email) # Access to a protected member _email of a class
# Out:
# noha@gmail.com

# %%
emp._email = 'updated@gmail.com'

# %% [markdown]
# - access private members

# %%
print(emp.__salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(emp.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %%
print(emp.city)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(emp.city)
#
# AttributeError: 'Employee' object has no attribute 'city'

# %%
print(emp.__dict__)
# Out:
# {'name': 'updated', '_email': 'updated@gmail.com', '_Employee__salary': 50000}

# %% [markdown]
# - Ethically don't this ? don't access protected members using object
# -

# %%
print(emp._Employee__salary)
# Out:
# 50000

# %% [markdown]
# <h1 style='color:pink; text-align:center;'>Introducing Getters and setters </h1>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.__salary = salary


    def salary(self):
        return self.__salary

emp = Employee("noha", 'noha@gmail.com', 50000)
print(emp.salary())
# Out:
# 50000

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.__salary = salary


    def salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")


emp = Employee("noha", 'noha@gmail.com', 50000)
print(emp.salary())

emp.set_salary(45645)

emp2= Employee("sadds", "aadad", "dasdads")
# Out:
# 50000

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")


    def salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", "dasdads")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 22
#      17         else:
#      18             raise TypeError("Salary must be an integer")
# ---> 22 emp2= Employee("sadds", "aadad", "dasdads")
#
# Cell In[16], line 8, in Employee.__init__(self, name, email, salary)
#       6     self.__salary = salary
#       7 else:
# ----> 8     raise TypeError("Salary must be a float")
#
# TypeError: Salary must be a float

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")


    def salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", 234)
# setting object property == instance variables
emp.name = 'updated' # deals with public member
print(emp.salary())
emp.set_salary(3248)  # deals with private member
# Out:
# 45645

# %% [markdown]
# <h1 style='color:green;'> Property decorator </h1>

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")

    @property  # this function represent the property
    # you can directly call it instanceName.salary
    def salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", 234)
print(emp2.salary)
print(emp2.salary())
# Out:
# 234
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 24
#      22 emp2= Employee("sadds", "aadad", 234)
#      23 print(emp2.salary)
# ---> 24 print(emp2.salary())
#
# TypeError: 'int' object is not callable

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")

    @property  # this function represent the property
    # you can directly call it instanceName.salary
    def salary(self):
        return self.__salary

    def set_salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", 234)
print(emp2.salary)
print(emp.__dict__)
# Out:
# 234
# {'name': 'updated', '_email': 'noha@gmail.com', '_Employee__salary': 3248}

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be a float")

    @property  # this function represent the property
    # you can directly call it instanceName.salary
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", 234)
print(emp2.salary)
print(emp2.__dict__)
emp2.salary = 5000
print(emp2.salary)
# Out:
# 234
# {'name': 'sadds', '_email': 'aadad', '_Employee__salary': 234}
# 5000

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self._email = email
        self.salary = salary


    @property  # this function represent the property
    # you can directly call it instanceName.salary
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, salary):
        if isinstance(salary, int) and salary > 0:
            self.__salary = salary
        else:
            raise TypeError("Salary must be an integer")



emp2= Employee("sadds", "aadad", 234)
print(emp2.salary)
print(emp2.__dict__)
emp2.salary = 5000
print(emp2.salary)
# Out:
# 234
# {'name': 'sadds', '_email': 'aadad', '_Employee__salary': 234}
# 5000
# 5000

# %%
class Student:
    def __init__(self, name, email, birthyear):
        self.name = name
        self.email = email
        self.birthyear = birthyear

    @property
    def age(self):
        return 2026 - self.birthyear


s = Student("sadds", "aadad", 2000)
print(s.age)
print(s.__dict__)
# Out:
# 26
# {'name': 'sadds', 'email': 'aadad', 'birthyear': 2000}

# %%
s.age = 29
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s.age = 29
#
# AttributeError: property 'age' of 'Student' object has no setter
