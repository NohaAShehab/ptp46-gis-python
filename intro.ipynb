# %%
print("hello world")
# Out:
# hello world

# %%
name = 'Ahmed'
num = 10
happy = True
money = None

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
isinstance(name, str)
# Out:
# True

# %%
print(isinstance(num, object))
# Out:
# True

# %% [markdown]
# # type conversion ?

# %%
# from int to string
num = 100 # int
print(num, type(num))
num = str(num)
print(num, type(num))
# Out:
# 100 <class 'int'>
# 100 <class 'str'>

# %%
# from string to int
year = "2026"
print(year, type(year))
year = int(year)
print(year, type(year))
# Out:
# 2026 <class 'str'>
# 2026 <class 'int'>

# %%
name = 'noha'
print(name, type(name))
name = int(name)
print(name, type(name))
# Out:
# noha <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 name = 'noha'
#       2 print(name, type(name))
# ----> 3 name = int(name)
#       4 print(name, type(name))
#
# ValueError: invalid literal for int() with base 10: 'noha'

# %%
print(True ==  1 )
# Out:
# True

# %%
print("10" == 10 ) # == compare value and datatype
# Out:
# False

# %%
print("iti" and "GIS")
# Out:
# GIS

# %%
print(bool("iti"))
# Out:
# True

# %%
print(bool("GIS"))
# Out:
# True

# %%
"""

    and return True ? --> all expression parts represent True

    "iti" and "GIS" and True and 10 ===>  10 (True )

    "iti" and "GIS" and "" and 10 ==> "" (False)

    # or ? return true if at least one of the expression parts reperenet true

    'iti' or 'gis' --> 'iti'

"""

# %%
name1 = 'ahmed'
name2 = "new"

# %%
print(100 and 10 and -1 )
# Out:
# -1

# %%
print(bool(100 and 10 and -1 ))
# Out:
# True

# %%
print(None and 10 and -1 )
# Out:
# None
