# %%
from time import pthread_getcpuclockid

""" string is sequence of characters """

iti = "information Technology institute"

# string is immutable datatype ? once created couldn't be changed ?

print(iti, type(iti))
# Out:
# information Technology institute <class 'str'>

# %%
print(len(iti))
# Out:
# 32

# %%
# count i in iti
print(iti.count("i"))
# Out:
# 4

# %%
# check char exists or not in the string
print('i' in iti)
# Out:
# True

# %%
# contact 2 strings
fname = 'Ahmed'
lname = 'Ali'
name = fname + ' ' + lname
print(name, type(name))
# Out:
# Ahmed Ali <class 'str'>

# %%
# string is treated like an array
# each char has index --> index start from 0 , access string parts using index
# slicing
print(iti)
print(iti[1:5]) # new string
# Out:
# information Technology institute
# nfor

# %%
print(iti[4:])
# Out:
# rmation Technology institute

# %%
print(iti[1:10])
print(iti[1:10:2])
# Out:
# nformatio
# nomto

# %%
print(iti[3])
# Out:
# o

# %%
print(iti[::])
# Out:
# information Technology institute

# %%
print(iti[::-1]) #  new string
# Out:
# etutitsni ygolonhceT noitamrofni

# %%
print(iti.index('i')) # return with the index of the first occurrence
# Out:
# 0

# %%
print(iti)
# Out:
# information Technology institute

# %%
counter  = 0
while counter < len(iti):
    char = iti[counter]
    if char =='i':
        print(counter)
    counter +=1
# Out:
# 0
# 8
# 23
# 27

# %%
# loop over the string
for c in iti:
    print(c)
# Out:
# i
# n
# f
# o
# r
# m
# a
# t
# i
# o
# n
#
# T
# e
# c
# h
# n
# o
# l
# o
# g
# y
#
# i
# n
# s
# t
# i
# t
# u
# t
# e

# %%
index = 0
for c in iti:
    if c == 'i':
        print(c, index)
    index +=1
# Out:
# i 0
# i 8
# i 23
# i 27

# %%
iti_enum = enumerate(iti)   # generate index for each char??
print(iti_enum)

# %%
for index, char in iti_enum:
    print(char, index)
# Out:
# i 0
# n 1
# f 2
# o 3
# r 4
# m 5
# a 6
# t 7
# i 8
# o 9
# n 10
#   11
# T 12
# e 13
# c 14
# h 15
# n 16
# o 17
# l 18
# o 19
# g 20
# y 21
#   22
# i 23
# n 24
# s 25
# t 26
# i 27
# t 28
# u 29
# t 30
# e 31

# %%
for index, char in iti_enum:
    if char == 'i':
        print(char, index)

# %%
for index, char in enumerate(iti):
    if char == 'i':
        print(char, index)
# Out:
# i 0
# i 8
# i 23
# i 27

# %%
iti_enum = enumerate(iti)
for index, char in iti_enum:
    if char == 'i':
        print(char, index)

# %%
# interpolation ?
fname = 'noha '
mid = 'abdelhady '
lname= 'shehab'

fullname = fname + " "+ mid + " " + mid + " " + lname
print(fullname, type(fullname))
# Out:
# noha  abdelhady  abdelhady  shehab <class 'str'>

# %%
fullname = fname + mid*2 + lname
print(fullname, type(fullname))
# Out:
# noha abdelhady abdelhady shehab <class 'str'>

# %%
iti = "information Technology institute"

print(iti.upper()) # new string
# Out:
# INFORMATION TECHNOLOGY INSTITUTE

# %%
print(iti.lower())
print(iti.title())
print(iti.capitalize())
# Out:
# information technology institute
# Information Technology Institute
# Information technology institute

# %%
anystr = "hello world" # o, with @

newstr = ""
for char in anystr:
    if char =='o':
        newstr += "@"
    else:
        newstr += char

print(newstr)
# Out:
# hell@ w@rld

# %%
anystr = "hello world"
newstr2 = anystr.replace('o', '@')
print(newstr2)
# Out:
# hell@ w@rld

# %%
# ask user to enter any value ??
username = input("Please enter your username: ") # always with string
print(username, type(username))
# Out:
# 87987 <class 'str'>

# %%
num1 = input("please enter num1: ")
num2 = input("please enter num2: ")
res = num1 + num2 # concat
print(res, type(res))
# Out:
# 2233 <class 'str'>

# %%
num1 = input("please enter num1: ")
num2 = input("please enter num2: ")
res = int(num1) + int(num2)# summation
print(res, type(res))
# Out:
# 55 <class 'int'>

# %%
num1 = input("please enter num1: ")
num2 = input("please enter num2: ")
res = int(num1) + int(num2)# summation
print(res, type(res))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 num1 = input("please enter num1: ")
#       2 num2 = input("please enter num2: ")
# ----> 3 res = int(num1) + int(num2)# summation
#       4 print(res, type(res))
#
# ValueError: invalid literal for int() with base 10: 'waeqwe'

# %% [markdown]
# <img src='userinput.jpeg'>

# %%
numm = input("please enter a number: ")
print(numm.isdigit())
# Out:
# True

# %%
numm = input("please enter a number: ")
print(numm.isdigit())
# Out:
# False

# %%
num1 = input("please enter num1: ")
num2 = input("please enter num2: ")
if num1.isdigit() and num2.isdigit():
    res = int(num1) + int(num2)# summation
    print(res, type(res))
else:
    print('-- num1 and num2 must be integers --')

# %%
username= 'Ahmed'
if username :
    print("hiii")
else:
    print("byee")

# %%
# formatting the string ??
# define template =>
description = "We are {0} students in {1} track"
print(description.format(16, "GIS"))  # return new string
# Out:
# We are 16 students in GIS track

# %%
description1 = "We are" + 16 + "students in "+ "GIS" + "track"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 description1 = "We are" + 16 + "students in "+ "GIS" + "track"
#
# TypeError: can only concatenate str (not "int") to str

# %%
description1 = "We are" + str(16) + "students in "+ "GIS" + "track"

# %%
description = "We are {0} students in {1} track"
print(description.format(16, "GIS"))
print(description.format(26, "AI"))
# Out:
# We are 16 students in GIS track
# We are 26 students in AI track

# %%
print(description.format(26, "AI",True, "new" ))
# Out:
# We are 26 students in AI track

# %%
description = "We are {0} students in {1} track {2}, {3}"
print(description.format(26, "AI"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 description = "We are {0} students in {1} track {2}, {3}"
# ----> 2 print(description.format(26, "AI"))
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
description = "We are {0} students in {1} track "
print(description.format(input("please enter num"), input("plz enter trakc")))
# Out:
# We are 233 students in 3wdds track

# %%
print(description.format("GIS", 16))
# Out:
# We are GIS students in 16 track

# %%
# use keyword param
description = "We are {std_num} students in {trackname} track"
print(description.format(trackname="GIS", std_num=16))
# Out:
# We are 16 students in GIS track

# %%
description = "We are {} students in {} track"
print(description)
# Out:
# We are {} students in {} track

# %%
print(description.format("GIS", 16))
# Out:
# We are GIS students in 16 track

# %%
# f-format string --> format, create string based on existing variables ??

newstr2 = f"Course is {coursename} {trackname}"
print(newstr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 # f-format string --> format, create string based on existing variables ??
# ----> 3 newstr2 = f"Course is {coursename} {trackname}"
#       4 print(newstr2)
#
# NameError: name 'coursename' is not defined

# %%
course_name = "Python"
track_name = "GIS"
str3 = f"course name is {course_name} for track {track_name}"
print(str3)
# Out:
# course name is Python for track GIS

# %%
message ="         hello from GIS                 "

msg2=  ""
for char in message:
    if char != ' ':
        msg2 += char

print(msg2)
# Out:
# hellofromGIS

# %%
message ="         hello from GIS                 "
print(len(message))
msg3 = message.strip() # remove whitespace from the beginning and the end of the string
# Out:
# 40

# %%
print(msg3, len(msg3))
# Out:
# hello from GIS 14

# %%
message ="         hello from GIS                 "
print(len(message))
msg3 = message.lstrip()
print(msg3, len(msg3))
# Out:
# 40
# hello from GIS                  31

# %%
# strip can strip whitespace or any specified chars.

closing = '...Python is easy, we learnt string, for ...'
print(closing.strip())
# Out:
# ...Python is easy, we learnt string, for ...

# %%
print(closing.strip(".")) # strip only dots from the string.
# Out:
# Python is easy, we learnt string, for

# %%
print(closing.strip(". rf"))
# Out:
# Python is easy, we learnt string, fo

# %%
"""
    noha --> 2
    'iti iti 2qwr iti'  ==> 3

    noha ==> nh
"""
